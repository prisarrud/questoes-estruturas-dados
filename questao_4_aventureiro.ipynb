# %% [markdown]
# # Questão 4 - Aventureiro
#
# Implemente uma solução para ajudar um aventureiro a atravessar um caminho nas ruínas de uma cidade para chegar em um destino muito bonito.
#
# Para isso, você deverá ler um arquivo `.txt` que representa esse mapa, com a seguinte legenda:
#
# | Símbolo | Significado |
# |---|---|
# | `E` | Entrada |
# | `D` | Destino |
# | `#` | Parede / caminho bloqueado |
# | `.` | Caminho livre |
#
# ### Mapa de exemplo
#
# ```text
# ####################
# E...#.......####...#
# ###.#.#####....#.###
# #...#.....#.#......#
# #.#####.#.#.####.#.#
# #.#.....#.#....#.#.#
# #.#.###.#.####.#...#
# #.#.#...######.#####
# #.....#...........D#
# ####################
# ```
#
# ### O que deve ser feito
#
# - Identificar a melhor estrutura de dados para representar o mapa e implementá-la.
# - Identificar e implementar o algoritmo para percorrer o mapa e atingir o destino.
# - Permitir que o caminho possa ser realizado de volta, sem que o aventureiro tenha que refazer caminhos inúteis.
# - O caminho de volta não pode ser um caminho novo: ele precisa voltar por onde veio, usando a rota mais eficiente.

# %% [markdown]
# ## Resolução
#
# > Desenvolva a solução abaixo.

# %%
# Escreva sua solução aqui
